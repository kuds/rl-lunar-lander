# %%
# !sudo apt install swig cmake -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.

# %%
# !pip install -r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt
# Out:
# Collecting stable-baselines3 (from -r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1))
#   Using cached stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting swig (from -r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 2))
#   Using cached swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.6 kB)
# Collecting gymnasium (from -r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 3))
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface_sb3 (from -r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5))
#   Using cached huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2.0.0.post304)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (3.8.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 3)) (4.11.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 3))
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 4))
#   Using cached box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl
# Collecting pygame>=2.1.3 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 4))
#   Using cached pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in /opt/conda/lib/python3.10/site-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (0.23.0)
# Requirement already satisfied: pyyaml~=6.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: wasabi in /opt/conda/lib/python3.10/site-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (23.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (4.66.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 5)) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->stable-baselines3->-r https://raw.githubusercontent.com/kuds/rl-lunar-lander/main/requirements.txt (line 1)) (1.3.0)
# Using cached stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
# Using cached swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Using cached huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Using cached pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)

# %% [markdown]
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install virtual screen libraries and create and run a virtual screen 🖥

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb

# %% [markdown]
# To make sure the new installed libraries are used, **sometimes it's required to restart the notebook runtime**. The next cell will force the **runtime to crash, so you'll need to connect again and run the code starting from here**. Thanks to this trick, **we will be able to run our virtual screen.**

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !pip install gymnasium huggingface_sb3 stable_baselines3 gymnasium[box2d]
# Out:
# Requirement already satisfied: gymnasium in /opt/conda/lib/python3.10/site-packages (0.29.1)
# Requirement already satisfied: huggingface_sb3 in /opt/conda/lib/python3.10/site-packages (3.0)
# Requirement already satisfied: stable_baselines3 in /opt/conda/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /opt/conda/lib/python3.10/site-packages (from huggingface_sb3) (0.23.0)
# Requirement already satisfied: pyyaml~=6.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_sb3) (6.0.1)
# Requirement already satisfied: wasabi in /opt/conda/lib/python3.10/site-packages (from huggingface_sb3) (1.1.2)
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from stable_baselines3) (2.0.0.post304)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from stable_baselines3) (2.1.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from stable_baselines3) (3.8.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame>=2.1.3 (from gymnasium[box2d])
#   Using cached pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting swig==4.* (from gymnasium[box2d])
#   Using cached swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (23.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.66.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->stable_baselines3) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->stable_baselines3) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Using cached swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
# Using cached pygame-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=494924 sha256=c1bac331504fb19e421f76cda32e9f4f13036742308dc45b8924d48c80bd933d
#   Stored in directory: /home/sagemaker-user/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py, pygame
# Successfully installed box2d-py-2.3.5 pygame-2.5.2 swig-4.2.1

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# 2024-06-10 19:50:50.510617: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-10 19:50:50.548408: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Understand Gymnasium and how it works 🤖
#
# 🏋 The library containing our environment is called Gymnasium.
# **You'll use Gymnasium a lot in Deep Reinforcement Learning.**
#
# Gymnasium is the **new version of Gym library** [maintained by the Farama Foundation](https://farama.org/).
#
# The Gymnasium library provides two things:
#
# - An interface that allows you to **create RL environments**.
# - A **collection of environments** (gym-control, atari, box2D...).
#
# Let's look at an example, but first let's recall the RL loop.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# At each step:
# - Our Agent receives a **state (S0)** from the **Environment** — we receive the first frame of our game (Environment).
# - Based on that **state (S0),** the Agent takes an **action (A0)** — our Agent will move to the right.
# - The environment transitions to a **new** **state (S1)** — new frame.
# - The environment gives some **reward (R1)** to the Agent — we’re not dead *(Positive Reward +1)*.
#
#
# With Gymnasium:
#
# 1️⃣ We create our environment using `gymnasium.make()`
#
# 2️⃣ We reset the environment to its initial state with `observation = env.reset()`
#
# At each step:
#
# 3️⃣ Get an action using our model (in our example we take a random action)
#
# 4️⃣ Using `env.step(action)`, we perform this action in the environment and get
# - `observation`: The new state (st+1)
# - `reward`: The reward we get after executing the action
# - `terminated`: Indicates if the episode terminated (agent reach the terminal state)
# - `truncated`: Introduced with this new version, it indicates a timelimit or if an agent go out of bounds of the environment for instance.
# - `info`: A dictionary that provides additional information (depends on the environment).
#
# For more explanations check this 👉 https://gymnasium.farama.org/api/env/#gymnasium.Env.step
#
# If the episode is terminated:
# - We reset the environment to its initial state with `observation = env.reset()`
#
# **Let's look at an example!** Make sure to read the code

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# Action taken: 2
# Action taken: 1
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 2
# Action taken: 2
# Action taken: 0
# Action taken: 1
# Action taken: 0

# %% [markdown]
# ## Create the LunarLander environment 🌛 and understand how it works
#
# ### [The environment 🎮](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# In this first tutorial, we’re going to train our agent, a [Lunar Lander](https://gymnasium.farama.org/environments/box2d/lunar_lander/), **to land correctly on the moon**. To do that, the agent needs to learn **to adapt its speed and position (horizontal, vertical, and angular) to land correctly.**
#
# ---
#
#
# 💡 A good habit when you start to use an environment is to check its documentation
#
# 👉 https://gymnasium.farama.org/environments/box2d/lunar_lander/
#
# ---

# %% [markdown]
# Let's see what the Environment looks like:

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-0.21517055 -0.26143482  3.632224   -1.1559669  -2.7076476  -3.5294943
#   0.5895469   0.94234484]

# %% [markdown]
# We see with `Observation Space Shape (8,)` that the observation is a vector of size 8, where each value contains different information about the lander:
# - Horizontal pad coordinate (x)
# - Vertical pad coordinate (y)
# - Horizontal speed (x)
# - Vertical speed (y)
# - Angle
# - Angular speed
# - If the left leg contact point has touched the land (boolean)
# - If the right leg contact point has touched the land (boolean)

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 3

# %% [markdown]
# The action space (the set of possible actions the agent can take) is discrete with 4 actions available 🎮:
#
# - Action 0: Do nothing,
# - Action 1: Fire left orientation engine,
# - Action 2: Fire the main engine,
# - Action 3: Fire right orientation engine.
#
# Reward function (the function that will give a reward at each timestep) 💰:
#
# After every step a reward is granted. The total reward of an episode is the **sum of the rewards for all the steps within that episode**.
#
# For each step, the reward:
#
# - Is increased/decreased the closer/further the lander is to the landing pad.
# -  Is increased/decreased the slower/faster the lander is moving.
# - Is decreased the more the lander is tilted (angle not horizontal).
# - Is increased by 10 points for each leg that is in contact with the ground.
# - Is decreased by 0.03 points each frame a side engine is firing.
# - Is decreased by 0.3 points each frame the main engine is firing.
#
# The episode receive an **additional reward of -100 or +100 points for crashing or landing safely respectively.**
#
# An episode is **considered a solution if it scores at least 200 points.**

# %% [markdown]
# #### Vectorized Environment
#
# - We create a vectorized environment (a method for stacking multiple independent environments into a single environment) of 16 environments, this way, **we'll have more diverse experiences during the training.**

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Create the Model 🤖
# - We have studied our environment and we understood the problem: **being able to land the Lunar Lander to the Landing Pad correctly by controlling left, right and main orientation engine**. Now let's build the algorithm we're going to use to solve this Problem 🚀.
#
# - To do so, we're going to use our first Deep RL library, [Stable Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/).
#
# - SB3 is a set of **reliable implementations of reinforcement learning algorithms in PyTorch**.
#
# ---
#
# 💡 A good habit when using a new library is to dive first on the documentation: https://stable-baselines3.readthedocs.io/en/master/ and then try some tutorials.
#
# ----

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/sb3.png" alt="Stable Baselines3">

# %% [markdown]
# To solve this problem, we're going to use SB3 **PPO**. [PPO (aka Proximal Policy Optimization) is one of the SOTA (state of the art) Deep Reinforcement Learning algorithms that you'll study during this course](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#example%5D).
#
# PPO is a combination of:
# - *Value-based reinforcement learning method*: learning an action-value function that will tell us the **most valuable action to take given a state and action**.
# - *Policy-based reinforcement learning method*: learning a policy that will **give us a probability distribution over actions**.

# %% [markdown]
# Stable-Baselines3 is easy to set up:
#
# 1️⃣ You **create your environment** (in our case it was done above)
#
# 2️⃣ You define the **model you want to use and instantiate this model** `model = PPO("MlpPolicy")`
#
# 3️⃣ You **train the agent** with `model.learn` and define the number of training timesteps
#
# ```
# # Create environment
# env = gym.make('LunarLander-v2')
#
# # Instantiate the agent
# model = PPO('MlpPolicy', env, verbose=1)
# # Train the agent
# model.learn(total_timesteps=int(2e5))
# ```

# %%
# TODO: Define a PPO MlpPolicy architecture
# We use MultiLayerPerceptron (MLPPolicy) because the input is a vector,
# if we had frames as input we would use CnnPolicy
model =
# Out:
#   Cell In[8], line 4
#     model =
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Solution

# %%
# SOLUTION
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %% [markdown]
# ## Train the PPO agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~20min, but you can use fewer timesteps if you just want to try it out.
# - During the training, take a ☕ break you deserved it 🤗

# %%
# TODO: Train it for 1,000,000 timesteps

# TODO: Specify file name for model and save the model to file
model_name = "ppo-LunarLander-v2"

# %% [markdown]
# #### Solution

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.5     |
# |    ep_rew_mean     | -178     |
# | time/              |          |
# |    fps             | 4090     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.5         |
# |    ep_rew_mean          | -136         |
# | time/                   |              |
# |    fps                  | 2907         |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066043446 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00209     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 5.21e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95           |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 2649         |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0074940627 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00331     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 727          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 2e+03        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.9        |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 2532        |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008599457 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000429   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 267         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 1e+03       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -99.8        |
# | time/                   |              |
# |    fps                  | 2469         |
# |    iterations           | 5            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0073091267 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00729     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 495          |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 761          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -96         |
# | time/                   |             |
# |    fps                  | 2408        |
# |    iterations           | 6           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006742323 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000262   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 455         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | -66.7       |
# | time/                   |             |
# |    fps                  | 2299        |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008579048 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.85e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 235         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 440         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 119      |
# |    ep_rew_mean          | -50.4    |
# | time/                   |          |
# |    fps                  | 2272     |
# |    iterations           | 8        |
# |    time_elapsed         | 57       |
# |    total_timesteps      | 131072   |
# | train/                  |          |
# |    approx_kl            | 0.00861  |
# |    clip_fraction        | 0.036    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.28    |
# |    explained_variance   | -0.00639 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 265      |
# |    n_updates            | 28       |
# |    policy_gradient_loss | -0.00641 |
# |    value_loss           | 319      |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | -34.8       |
# | time/                   |             |
# |    fps                  | 2213        |
# |    iterations           | 9           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.008487745 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.9        |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 314         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -17.9       |
# | time/                   |             |
# |    fps                  | 2123        |
# |    iterations           | 10          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008051871 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 283         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | -21.2       |
# | time/                   |             |
# |    fps                  | 2034        |
# |    iterations           | 11          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.007285293 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 292         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | -12.9        |
# | time/                   |              |
# |    fps                  | 1862         |
# |    iterations           | 12           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0040286016 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 317          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | -4.71        |
# | time/                   |              |
# |    fps                  | 1693         |
# |    iterations           | 13           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0052337423 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 254          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 418         |
# |    ep_rew_mean          | 11.6        |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 14          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.007057798 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.1        |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 191         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 480          |
# |    ep_rew_mean          | 20.5         |
# | time/                   |              |
# |    fps                  | 1466         |
# |    iterations           | 15           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0047883634 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.7         |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 138          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 573         |
# |    ep_rew_mean          | 33.3        |
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 16          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.007298679 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 115         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 611        |
# |    ep_rew_mean          | 40.3       |
# | time/                   |            |
# |    fps                  | 1310       |
# |    iterations           | 17         |
# |    time_elapsed         | 212        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.00735899 |
# |    clip_fraction        | 0.0451     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 65.8       |
# |    n_updates            | 64         |
# |    policy_gradient_loss | -0.00232   |
# |    value_loss           | 82.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | 52.5        |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 18          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.006300103 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 79          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | 61.1        |
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 19          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.005959163 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 59.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 748          |
# |    ep_rew_mean          | 66.1         |
# | time/                   |              |
# |    fps                  | 1191         |
# |    iterations           | 20           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0062123714 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.6         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 109          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 79.3         |
# | time/                   |              |
# |    fps                  | 1161         |
# |    iterations           | 21           |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0065068426 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 41.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 775          |
# |    ep_rew_mean          | 83.6         |
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 22           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0033095647 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.3         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000269    |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 812         |
# |    ep_rew_mean          | 84.4        |
# | time/                   |             |
# |    fps                  | 1107        |
# |    iterations           | 23          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.007252141 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 39.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 863          |
# |    ep_rew_mean          | 91.2         |
# | time/                   |              |
# |    fps                  | 1084         |
# |    iterations           | 24           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0061433376 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.3         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000776    |
# |    value_loss           | 36           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 880         |
# |    ep_rew_mean          | 95.7        |
# | time/                   |             |
# |    fps                  | 1062        |
# |    iterations           | 25          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.005749411 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.000671   |
# |    value_loss           | 73          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 895          |
# |    ep_rew_mean          | 92.4         |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 26           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0064956383 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.8         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 55.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 935         |
# |    ep_rew_mean          | 93.5        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 27          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005835578 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 34          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 938         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 28          |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.004150388 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 30.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 996          |
# |    iterations           | 29           |
# |    time_elapsed         | 476          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0046415394 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 47.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 918         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 986         |
# |    iterations           | 30          |
# |    time_elapsed         | 498         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004672043 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.7         |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.000694   |
# |    value_loss           | 21.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 976          |
# |    iterations           | 31           |
# |    time_elapsed         | 520          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0043463646 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.44         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 19.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 942          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 967          |
# |    iterations           | 32           |
# |    time_elapsed         | 542          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0047286153 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 20.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 934          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 33           |
# |    time_elapsed         | 562          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0075042313 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000804    |
# |    value_loss           | 3.81         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 922          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 34           |
# |    time_elapsed         | 582          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0035657329 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -3.83e-05    |
# |    value_loss           | 12.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 922          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 953          |
# |    iterations           | 35           |
# |    time_elapsed         | 601          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0066150795 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000944    |
# |    value_loss           | 22.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 922        |
# |    ep_rew_mean          | 134        |
# | time/                   |            |
# |    fps                  | 950        |
# |    iterations           | 36         |
# |    time_elapsed         | 620        |
# |    total_timesteps      | 589824     |
# | train/                  |            |
# |    approx_kl            | 0.00665001 |
# |    clip_fraction        | 0.0514     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.64       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.000943  |
# |    value_loss           | 32.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 905         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 947         |
# |    iterations           | 37          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.005857111 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 897         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 38          |
# |    time_elapsed         | 658         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.004804804 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.52        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.001      |
# |    value_loss           | 26.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 39           |
# |    time_elapsed         | 677          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0037053265 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000643    |
# |    value_loss           | 13.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 913         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 40          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.006907656 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000977   |
# |    value_loss           | 13.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 929        |
# |    ep_rew_mean          | 144        |
# | time/                   |            |
# |    fps                  | 939        |
# |    iterations           | 41         |
# |    time_elapsed         | 715        |
# |    total_timesteps      | 671744     |
# | train/                  |            |
# |    approx_kl            | 0.00570113 |
# |    clip_fraction        | 0.0332     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.963     |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.53       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -7.75e-05  |
# |    value_loss           | 19         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 929         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 42          |
# |    time_elapsed         | 734         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004827011 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.612       |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 9.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 929         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 43          |
# |    time_elapsed         | 752         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.004094162 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.000931   |
# |    value_loss           | 27.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 933          |
# |    iterations           | 44           |
# |    time_elapsed         | 772          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0039456077 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.888       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4          |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.000443    |
# |    value_loss           | 13.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 913         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 45          |
# |    time_elapsed         | 790         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.002279476 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1         |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000273   |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 929         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 46          |
# |    time_elapsed         | 808         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.004149422 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000224   |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 937          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 930          |
# |    iterations           | 47           |
# |    time_elapsed         | 827          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0043552835 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.749        |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000377    |
# |    value_loss           | 2.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 48           |
# |    time_elapsed         | 846          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0045361626 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.885       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.82         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000553    |
# |    value_loss           | 12.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 926          |
# |    iterations           | 49           |
# |    time_elapsed         | 866          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0049486808 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.847       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.496        |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000732    |
# |    value_loss           | 2.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 976          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 50           |
# |    time_elapsed         | 885          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0031805288 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | 0.000393     |
# |    value_loss           | 2            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 973          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 51           |
# |    time_elapsed         | 904          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0044576596 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.683        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 1.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 942          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 52           |
# |    time_elapsed         | 921          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0041481573 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000438    |
# |    value_loss           | 57.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 53           |
# |    time_elapsed         | 939          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0041543944 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.5         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000947    |
# |    value_loss           | 43.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 921          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 924          |
# |    iterations           | 54           |
# |    time_elapsed         | 957          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0043095364 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.3         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 69.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 874          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 925          |
# |    iterations           | 55           |
# |    time_elapsed         | 974          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0042496454 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.341        |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 24.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 871          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 925          |
# |    iterations           | 56           |
# |    time_elapsed         | 991          |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0025817335 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.3         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000839    |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 834         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 57          |
# |    time_elapsed         | 1007        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.003326023 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64        |
# |    n_updates            | 224         |
# |    policy_gradient_loss | -0.000705   |
# |    value_loss           | 80.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 728         |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 58          |
# |    time_elapsed         | 1022        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.006057429 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 188         |
# |    n_updates            | 228         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 188         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 592          |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 932          |
# |    iterations           | 59           |
# |    time_elapsed         | 1036         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0047158115 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 181          |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 382          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 442          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 936          |
# |    iterations           | 60           |
# |    time_elapsed         | 1049         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0037829608 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.7         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 422          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 363          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 61           |
# |    time_elapsed         | 1061         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0071548093 |
# |    clip_fraction        | 0.0841       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 341          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 62           |
# |    time_elapsed         | 1072         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0057025165 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.5         |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 219          |
# ------------------------------------------

# %% [markdown]
# ## Evaluate the agent 📈
# - Remember to wrap the environment in a [Monitor](https://stable-baselines3.readthedocs.io/en/master/common/monitor.html).
# - Now that our Lunar Lander agent is trained 🚀, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`.
# - To fill that part you need to [check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)
# - In the next step,  we'll see **how to automatically evaluate and share your agent to compete in a leaderboard, but for now let's do it ourselves**
#
#
# 💡 When you evaluate your agent, you should not use your training environment but create an evaluation environment.

# %%
# TODO: Evaluate the agent
# Create a new environment for evaluation
eval_env =

# Evaluate the model with 10 evaluation episodes and deterministic=True
mean_reward, std_reward =

# Print the results

# %% [markdown]
# #### Solution

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=266.73 +/- 15.376685426243018

# %% [markdown]
# - In my case, I got a mean reward of `200.20 +/- 20.80` after training for 1 million steps, which means that our lunar lander agent is ready to land on the moon 🌛🥳.

# %% [markdown]
# ## Publish our trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20
#
# Here's an example of a Model Card (with Space Invaders):

# %% [markdown]
# By using `package_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account on Hugging Face ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# Let's fill the `package_to_hub` function:
# - `model`: our trained model.
# - `model_name`: the name of the trained model that we defined in `model_save`
# - `model_architecture`: the model architecture we used, in our case PPO
# - `env_id`: the name of the environment, in our case `LunarLander-v2`
# - `eval_env`: the evaluation environment defined in eval_env
# - `repo_id`: the name of the Hugging Face Hub Repository that will be created/updated `(repo_id = {username}/{repo_name})`
#
# 💡 **A good name is {username}/{model_architecture}-{env_id}**
#
# - `commit_message`: message of the commit

# %%
import gymnasium as gym
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

## TODO: Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id =

# TODO: Define the name of the environment
env_id =

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: Monitor(gym.make(env_id, render_mode="rgb_array"))])


# TODO: Define the model architecture we used
model_architecture = ""

## TODO: Define the commit message
commit_message = ""

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)

# %% [markdown]
# #### Solution

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "ThomasSimonini/ppo-LunarLander-v2" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Reinforcement Learning agent. The script above should have displayed a link to a model repository such as https://huggingface.co/osanseviero/test_sb3. When you go to this link, you can:
# * See a video preview of your agent at the right.
# * Click "Files and versions" to see all the files in the repository.
# * Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# * A model card (`README.md` file) which gives a description of the model
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# Compare the results of your LunarLander-v2 with your classmates using the leaderboard 🏆 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# ## Load a saved LunarLander model from the Hub 🤗
# Thanks to [ironbar](https://github.com/ironbar) for the contribution.
#
# Loading a saved model from the Hub is really easy.
#
# You go to https://huggingface.co/models?library=stable-baselines3 to see the list of all the Stable-baselines3 saved models.
# 1. You select one and copy its repo_id
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/copy-id.png" alt="Copy-id"/>

# %% [markdown]
# 2. Then we just need to use load_from_hub with:
# - The repo_id
# - The filename: the saved model inside the repo and its extension (*.zip)

# %% [markdown]
# Because the model I download from the Hub was trained with Gym (the former version of Gymnasium) we need to install shimmy a API conversion tool that will help us to run the environment correctly.
#
# Shimmy Documentation: https://github.com/Farama-Foundation/Shimmy

# %%
# !pip install shimmy

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)

# %% [markdown]
# Let's evaluate this agent:

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! As you saw, the current agent is not doing great. As a first suggestion, you can train for more steps. With 1,000,000 steps, we saw some great results!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here are some ideas to achieve so:
# * Train more steps
# * Try different hyperparameters for `PPO`. You can see them at https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters.
# * Check the [Stable-Baselines3 documentation](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) and try another model such as DQN.
# * **Push your new trained model** on the Hub 🔥
#
# **Compare the results of your LunarLander-v2 with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆
#
# Is moon landing too boring for you? Try to **change the environment**, why not use MountainCar-v0, CartPole-v1 or CarRacing-v0? Check how they work [using the gym documentation](https://www.gymlibrary.dev/) and have fun 🎉.

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter! That was the biggest one, **and there was a lot of information.**
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and have a solid foundations.
#
# Naturally, during the course, we’re going to dive deeper into these concepts but **it’s better to have a good understanding of them now before diving into the next chapters.**

# %% [markdown]
# Next time, in the bonus unit 1, you'll train Huggy the Dog to fetch the stick.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/huggy.jpg" alt="Huggy"/>
#
# ## Keep learning, stay awesome 🤗
